# %% [markdown]
# # Project 3 -- [Adam] [Ornelas]

# %% [markdown]
# ## Notes

# %%
import pandas as pd
#Creating a data frame with a unique csv file
myDF = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|')
myDF.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]

# %%
#this code allows the code below to show all states sumns
pd.set_option('display.max_rows', None)

# %%
#Example of how to use groupby
#Looks at the transactions by state
#summing the transaction amount by state
myDF.groupby('STATE')['TRANSACTION_AMT'].sum()
# Out:
# STATE
# 01        1550
# AK      531485
# AL     2596149
# AR      954867
# AS        1500
# AZ     2178217
# BE         750
# CA    24085171
# CO     2708667
# CT     5328197
# CZ         950
# DC     5689543
# DE      595008
# EL        1000
# FL    10514203
# GA     4201705
# GU       29835
# HI      610401
# IA     1279935
# ID      543468
# IL     9105545
# IN     2518579
# KS     2230356
# KY     1536043
# LA     4394374
# MA     4233203
# MD     2660154
# ME      311825
# MI     4585088
# MN     2454049
# MO     3211817
# MS     1147941
# MT      288802
# NC     1644856
# ND      119115
# NE      508252
# NH      861868
# NJ     4489040
# NM      668358
# NV     1490702
# NY    18673301
# OH     7237330
# OK     5047135
# OR     1093271
# PA     5705339
# PR      385311
# RI      495636
# SC     1371766
# SD      295014
# TN     3043735
# TU         250
# TX    24472610
# UT      681255
# VA     2830422
# VI       75350
# VT      207943
# WA     1872939
# WI     1342009
# ...

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
#Importing airplane df
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/1990.csv")

# %%
#the code below helps show the columns better because this df has a lot of columns
pd.set_option('display.max_columns', None)
myDF.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1990      1           3          3   1707.0        1630   1755.0
# 1  1990      1           4          4   1706.0        1630   1807.0
# 2  1990      1           5          5   1629.0        1630   1715.0
# 3  1990      1           6          6   1633.0        1630   1718.0
# 4  1990      1           8          1   1630.0        1630   1726.0
#
#    CRSArrTime UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  \
# 0        1723            US         29      NaN               48.0
# 1        1723            US         29      NaN               61.0
# 2        1723            US         29      NaN               46.0
# 3        1723            US         29      NaN               45.0
# 4        1723            US         29      NaN               56.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# ...

# %%
#Grouping the average delays by looking at each destination airport
myDF.groupby('Dest')['ArrDelay'].mean()
#The rows are in alphabetical order
# Out:
# Dest
# ABE     4.774940
# ABQ     7.772013
# ACY     5.588076
# AGS     8.358385
# ALB     7.511260
#          ...
# VPS     1.171456
# WRG     8.794408
# YAK     7.709576
# YAP    23.293233
# YUM     3.883364
# Name: ArrDelay, Length: 236, dtype: float64

# %% [markdown]
# ## Question 2

# %%
#Uploading the grocery store df
myDF = pd.read_csv('/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv')
myDF.columns = ["BASKET_NUM", "HSHD_NUM", "PURCHASE", "PRODUCT_NUM", "SPEND", "UNITS", "STORE_R", "WEEK_NUM", "YEAR"]
myDF.head()
# Out:
#    BASKET_NUM  HSHD_NUM   PURCHASE  PRODUCT_NUM  SPEND  UNITS  STORE_R  \
# 0          24      1809  03-JAN-16      5817389  -1.50     -1  SOUTH
# 1          24      1809  03-JAN-16      5829886  -1.50     -1  SOUTH
# 2          34      1253  03-JAN-16       539501   2.19      1  EAST
# 3          60      1595  03-JAN-16      5260099   0.99      1  WEST
# 4          60      1595  03-JAN-16      4535660   2.50      2  WEST
#
#    WEEK_NUM  YEAR
# 0         1  2016
# 1         1  2016
# 2         1  2016
# 3         1  2016
# 4         1  2016

# %%
myDF.groupby('STORE_R')['SPEND'].sum()
#here we group the sum of each region
#There are 4 regions and EAST has the largest SPEND
# Out:
# STORE_R
# CENTRAL     8897305.14
# EAST       11699446.86
# SOUTH       7957920.77
# WEST        9680106.54
# Name: SPEND, dtype: float64

# %% [markdown]
# ## Question 3

# %%
#We are using the previous df to see how much moneywas spent in 2016
#it only shows 2 years so that is why we use one column
#If it had many years we would probably have to modify the code more
myDF.groupby('YEAR')['SPEND'].sum()
# Out:
# YEAR
# 2016    19051720.01
# 2017    19183059.30
# Name: SPEND, dtype: float64

# %% [markdown]
# ## Question 4

# %%
#We are loading the olympics df
myDF = pd.read_csv('/anvil/projects/tdm/data/olympics/athlete_events.csv')

# %%
#We know the country column is NOC we need to find the height column
myDF.head()
#We see it is called 'Height'
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#We use this code to show every country 
pd.set_option('display.max_rows', None)
#Now we can group the height by country
myDF.groupby('NOC')['Height'].mean()
# Out:
# NOC
# AFG    170.592593
# AHO    177.294118
# ALB    173.000000
# ALG    174.702869
# AND    173.703704
# ANG    178.204082
# ANT    175.121739
# ANZ    176.730769
# ARG    176.604722
# ARM    171.937799
# ARU    173.219512
# ASA    175.666667
# AUS    176.874017
# AUT    177.369686
# AZE    172.717391
# BAH    177.440678
# BAN    166.187500
# BAR    176.598958
# BDI    172.631579
# BEL    176.143175
# BEN    173.683333
# BER    177.405797
# BHU    166.517241
# BIH    178.633929
# BIZ    175.054795
# BLR    174.256440
# BOH    174.000000
# BOL    171.295652
# BOT    175.809524
# BRA    177.637147
# BRN    173.424528
# BRU    166.111111
# BUL    172.830911
# BUR    176.000000
# CAF    179.276596
# CAM    166.719298
# CAN    174.978716
# CAY    179.506849
# CGO    174.585366
# CHA    176.558824
# CHI    174.986989
# CHN    172.602743
# CIV    176.415094
# CMR    173.634615
# COD    175.358209
# COK    171.324324
# COL    169.915220
# COM    170.866667
# CPV    175.888889
# ...

# %% [markdown]
# ## Question 5

# %%
#Now we will find the average height of each athlete based on each sport 
#We are still using the olympics df 
myDF.groupby('Sport')['Height'].mean()
# Out:
# Sport
# Aeronautics                         NaN
# Alpine Skiing                173.489052
# Alpinism                            NaN
# Archery                      173.203085
# Art Competitions             174.644068
# Athletics                    176.256268
# Badminton                    174.178803
# Baseball                     182.599291
# Basketball                   190.869879
# Basque Pelota                       NaN
# Beach Volleyball             186.144954
# Biathlon                     174.034766
# Bobsleigh                    181.437500
# Boxing                       172.825688
# Canoeing                     178.539568
# Cricket                             NaN
# Croquet                             NaN
# Cross Country Skiing         173.249185
# Curling                      174.203125
# Cycling                      176.108826
# Diving                       166.634264
# Equestrianism                174.375272
# Fencing                      177.164177
# ...

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
