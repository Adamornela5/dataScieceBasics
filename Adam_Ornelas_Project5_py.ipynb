# %% [markdown]
# # Project 5 -- [Adam] [Ornelas]

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
df = pd.read_csv("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
df.head()
#Importing a new df
# Out:
#    Id  ResidentStatus  Education1989Revision  Education2003Revision  \
# 0   1               1                      0                      2
# 1   2               1                      0                      2
# 2   3               1                      0                      7
# 3   4               1                      0                      6
# 4   5               1                      0                      3
#
#    EducationReportingFlag  MonthOfDeath Sex  AgeType  Age  \
# 0                       1             1   M        1   87
# 1                       1             1   M        1   58
# 2                       1             1   F        1   75
# 3                       1             1   M        1   74
# 4                       1             1   M        1   64
#
#    AgeSubstitutionFlag  ...  CauseRecode39  NumberOfEntityAxisConditions  \
# 0                    0  ...             24                             1
# ...

# %%
#creating a subset
f_df = df[df['Sex'] == "F"]
f_df.head()
#creating a subset by choosing only females
# Out:
#     Id  ResidentStatus  Education1989Revision  Education2003Revision  \
# 2    3               1                      0                      7
# 5    6               1                      0                      5
# 8    9               1                      0                      3
# 10  11               1                      0                      3
# 12  13               1                      0                      4
#
#     EducationReportingFlag  MonthOfDeath Sex  AgeType  Age  \
# 2                        1             1   F        1   75
# 5                        1             1   F        1   93
# 8                        1             1   F        1   86
# 10                       1             1   F        1   79
# 12                       1             1   F        1   85
#
#     AgeSubstitutionFlag  ...  CauseRecode39  NumberOfEntityAxisConditions  \
# 2                     0  ...             28                             2
# ...

# %%
age_sub = f_df[f_df['Age'] != 999]
#creating a subset of that drops an values with the age == 999
f_age= age_sub['Age'].value_counts()

# %%
import matplotlib.pyplot as plt
plt.bar(f_age.index, f_age)
# Out:
# <BarContainer object of 114 artists>

# %%
#I did not see it necessary to use sort_index() for this problem because we were just graphing the points and the graph looks the same
#regardless if the values were sorted

# %%
female_sub = df[(df['Sex'] == "F") & (df['Age'] != 999)]
female_sub.head(100)
#The new subset with advanced method
# Out:
#       Id  ResidentStatus  Education1989Revision  Education2003Revision  \
# 2      3               1                      0                      7
# 5      6               1                      0                      5
# 8      9               1                      0                      3
# 10    11               1                      0                      3
# 12    13               1                      0                      4
# ..   ...             ...                    ...                    ...
# 220  221               1                      0                      3
# 221  222               2                      0                      3
# 231  232               1                      0                      3
# 232  233               1                      0                      3
# 235  236               2                      0                      4
#
#      EducationReportingFlag  MonthOfDeath Sex  AgeType  Age  \
# ...

# %% [markdown]
# ## Question 2

# %%
import pandas as pd
df = pd.read_csv("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
df.head()
#rename columns
df.columns = ["BASKET_NUM", "HSHD_NUM", "PURCHASE", "PRODUCT_NUM", "SPEND", "UNITS", "STORE_R", "WEEK_NUM", "YEAR"]

# %%
print(df.shape)
#checking shape
# Out:
# (10625553, 9)

# %%
refundsdf = df[df['SPEND'] < 0]
refundsdf.head()
#How spend has to be called
# Out:
#      BASKET_NUM  HSHD_NUM   PURCHASE  PRODUCT_NUM  SPEND  UNITS  STORE_R  \
# 0            24      1809  03-JAN-16      5817389  -1.50     -1  SOUTH
# 1            24      1809  03-JAN-16      5829886  -1.50     -1  SOUTH
# 92         4955      2570  06-JAN-16      5391980  -0.38      1  WEST
# 354       28557      3153  22-JAN-16      5184651  -3.42      9  CENTRAL
# 761       62654      4172  15-FEB-16       300529  -0.71      1  EAST
#
#      WEEK_NUM  YEAR
# 0           1  2016
# 1           1  2016
# 92          1  2016
# 354         3  2016
# 761         7  2016

# %%
print(refundsdf.shape)
#checking new shape
#it got smaller
# Out:
# (12646, 9)

# %%
storeRef = refundsdf['STORE_R'].value_counts()
#counting all the times theres a refund 
storeRef.head()
#Showing the amount of refunds
# Out:
# STORE_R
# WEST       3952
# EAST       3269
# CENTRAL    2750
# SOUTH      2675
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(storeRef.index, storeRef)
#This code shows how many refunds each store has
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Question 3

# %%
import pandas as pd
df = pd.read_csv('/anvil/projects/tdm/data/beer/reviews_sample.csv')
df.head()
# Out:
#    beer_id         username        date  \
# 0   271781     bluejacket74  2017-03-17
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
#
#                                                 text  look  smell  taste  \
# 0     750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
#
#    feel  overall  score
# 0  4.25     4.00   4.03
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31

# %%
newDf = df[(df['score'] != 5) & (df['overall'] == 5)]
print(newDf.shape)
newDf.head()
#Creating a new df by scores that are not 5 and overall is 5
# Out:
# (12436, 10)
#      beer_id    username        date  \
# 5     125646     jneff33  2017-12-20
# 295   125646      JonB25  2017-11-04
# 354    58482    JoePetto  2009-06-07
# 470   125646  HankSingle  2017-10-26
# 473   125646  bubseymour  2017-10-26
#
#                                                   text  look  smell  taste  \
# 5                                                       4.50   4.75    5.0
# 295                                                     5.00   4.75    5.0
# 354     On draft at TND in Wayne in 13oz wide beer ...  4.50   4.50    5.0
# 470     Goodness, me. A gift from a friend, just ba...  4.75   5.00    5.0
# 473     Do you really need another review? What’s n...  5.00   4.75    5.0
#
#      feel  overall  score
# 5     5.0      5.0   4.91
# 295   5.0      5.0   4.94
# 354   5.0      5.0   4.85
# 470   5.0      5.0   4.99
# 473   5.0      5.0   4.94

# %%
#This new sub data frame of people who have an overall score of 5 but with a score that does not equal 5 has 12436 rows

# %% [markdown]
# ## Question 4

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|')

myDF.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
myDF.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# ...

# %%
missingTran = myDF[myDF['TRANSACTION_DT'].isnull()]
missingTran.head()
#checking for missing values in transaction dt to see who is missing a transaction
# Out:
#         CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 8739  C00097121         N    TER             NaN  79011650894            15C
# 8740  C00097121         N    TER             NaN  79011650894            15C
# 8741  C00097121         N    TER             NaN  79011650894            15C
# 8742  C00097121         N    TER             NaN  79011650894            15C
# 8743  C00097121         N    TER             NaN  79011650894            15C
#
#       ENTITY_TP                     NAME CITY STATE  ...  EMPLOYER OCCUPATION  \
# 8739        NaN  SCHECK, RICHARD HERBERT  NaN   NaN  ...       NaN        NaN
# 8740        NaN  SCHECK, RICHARD HERBERT  NaN   NaN  ...       NaN        NaN
# 8741        NaN  SCHECK, RICHARD HERBERT  NaN   NaN  ...       NaN        NaN
# 8742        NaN  SCHECK, RICHARD HERBERT  NaN   NaN  ...       NaN        NaN
# 8743        NaN  SCHECK, RICHARD HERBERT  NaN   NaN  ...       NaN        NaN
#
# ...

# %%
#According to the code the last person was SHECK, RICHARD HERBERT

# %% [markdown]
# ## Question 5

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/1990.csv")
myDF.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1990      1           3          3   1707.0        1630   1755.0
# 1  1990      1           4          4   1706.0        1630   1807.0
# 2  1990      1           5          5   1629.0        1630   1715.0
# 3  1990      1           6          6   1633.0        1630   1718.0
# 4  1990      1           8          1   1630.0        1630   1726.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 0        1723            US         29  ...     NaN      NaN          0
# 1        1723            US         29  ...     NaN      NaN          0
# 2        1723            US         29  ...     NaN      NaN          0
# 3        1723            US         29  ...     NaN      NaN          0
# 4        1723            US         29  ...     NaN      NaN          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df1 = myDF[(myDF['DepDelay'].isna()) & (myDF['ArrDelay'].isna())]
print(df1.shape)
df1.head()
#It seems as if there are 52458 flights that dont have a record of depdelay or ArrDelay
# Out:
# (52458, 29)
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 179  1990      1           1          1      NaN         730      NaN
# 385  1990      1          29          1      NaN        2100      NaN
# 484  1990      1           8          1      NaN        1840      NaN
# 661  1990      1           8          1      NaN        2050      NaN
# 679  1990      1          29          1      NaN        2050      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 179         856            US         31  ...     NaN      NaN          1
# 385        2159            US         34  ...     NaN      NaN          1
# 484        1927            US         35  ...     NaN      NaN          1
# 661        2203            US         38  ...     NaN      NaN          1
# 679        2203            US         38  ...     NaN      NaN          1
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df2 = myDF[(myDF['DepDelay'].notna()) & (myDF['ArrDelay'].isna())]
print(df2.shape)
df2.head()
#The code for DepDelay present and not the ArrDelay present
#Theres 15954 flights
# Out:
# (15954, 29)
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 104  1990      1          17          3   1859.0        1430      NaN
# 214  1990      1           5          5   1024.0         945      NaN
# 222  1990      1          13          6   1014.0         945      NaN
# 223  1990      1          14          7   1053.0         945      NaN
# 953  1990      1           4          4   1654.0        1640      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 104        1554            US         29  ...     NaN      NaN          0
# 214        1215            US         31  ...     NaN      NaN          0
# 222        1215            US         31  ...     NaN      NaN          0
# 223        1215            US         31  ...     NaN      NaN          0
# 953        1806            US         42  ...     NaN      NaN          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
