# %% [markdown]
# # Project 6 -- [Adam] [Ornelas]

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
df = pd.read_csv("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
#Creating new df

# %%
df.head()
#Looking At the head
# Out:
#    Id  ResidentStatus  Education1989Revision  Education2003Revision  \
# 0   1               1                      0                      2
# 1   2               1                      0                      2
# 2   3               1                      0                      7
# 3   4               1                      0                      6
# 4   5               1                      0                      3
#
#    EducationReportingFlag  MonthOfDeath Sex  AgeType  Age  \
# 0                       1             1   M        1   87
# 1                       1             1   M        1   58
# 2                       1             1   F        1   75
# 3                       1             1   M        1   74
# 4                       1             1   M        1   64
#
#    AgeSubstitutionFlag  ...  CauseRecode39  NumberOfEntityAxisConditions  \
# 0                    0  ...             24                             1
# ...

# %%
df['Race'].value_counts()
#These are all the races represented in numbers
#there are 11074 Filipinos
# Out:
# Race
# 1     2241510
# 2      309504
# 3       18031
# 4       13297
# 7       11074
# 68       8737
# 5        8159
# 18       6778
# 48       4913
# 28       4711
# 78       2818
# 6         700
# 38        623
# 58        316
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
Fdf = df['Age'][(df['Race'] == 7) & (df['Age'] != 999)].value_counts()
plt.bar(Fdf.index, Fdf)
#This is a plot of all the death ages 
#it specifically looks at filipinos
#we isolated the filipinos then looks at all the deaths according to age.
# Out:
# <BarContainer object of 108 artists>

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
import pandas as pd 
df = pd.read_csv("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
df.columns = ["BASKET_NUM", "HSHD_NUM", "PURCHASE", "PRODUCT_NUM", "SPEND", "UNITS", "STORE_R", "WEEK_NUM", "YEAR"]
df.head()
# Out:
#    BASKET_NUM  HSHD_NUM   PURCHASE  PRODUCT_NUM  SPEND  UNITS  STORE_R  \
# 0          24      1809  03-JAN-16      5817389  -1.50     -1  SOUTH
# 1          24      1809  03-JAN-16      5829886  -1.50     -1  SOUTH
# 2          34      1253  03-JAN-16       539501   2.19      1  EAST
# 3          60      1595  03-JAN-16      5260099   0.99      1  WEST
# 4          60      1595  03-JAN-16      4535660   2.50      2  WEST
#
#    WEEK_NUM  YEAR
# 0         1  2016
# 1         1  2016
# 2         1  2016
# 3         1  2016
# 4         1  2016

# %%
df['STORE_R'][df['SPEND'] < 0].value_counts()
#Instead of creating a subset we are looking at the amount of refunds each store has with a table
# Out:
# STORE_R
# WEST       3952
# EAST       3269
# CENTRAL    2750
# SOUTH      2675
# Name: count, dtype: int64

# %% [markdown]
# ## Question 3

# %%
import pandas as pd
df = pd.read_csv("/anvil/projects/tdm/data/beer/reviews_sample.csv")
df.head()
# Out:
#    beer_id         username        date  \
# 0   271781     bluejacket74  2017-03-17
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
#
#                                                 text  look  smell  taste  \
# 0     750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
#
#    feel  overall  score
# 0  4.25     4.00   4.03
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31

# %%
df['username'].value_counts().head(10)
#Using sort and tail was not necessary 
#Values already gives us the top 10 names
#We just have to use head
# Out:
# username
# acurtis          1646
# StonedTrippin    1630
# kylehay2004      1628
# Sammy            1591
# Texasfan549      1532
# jaydoc           1489
# UCLABrewN84      1481
# kjkinsey         1335
# GRG1313          1287
# Knapp85          1264
# Name: count, dtype: int64

# %%
df['score'][df['username'] == 'acurtis'].mean()
#Grabbing the average score of the highest reviewer
# Out:
# 3.6558019441069263

# %% [markdown]
# ## Question 4

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|')

myDF.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
myDF.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# ...

# %%
myDF['NAME'][myDF['TRANSACTION_DT'].isna()]
#The 9 name values where transaction is missing 
#Grabbing all the names given that transaction in NA
# Out:
# 8739      SCHECK, RICHARD HERBERT
# 8740      SCHECK, RICHARD HERBERT
# 8741      SCHECK, RICHARD HERBERT
# 8742      SCHECK, RICHARD HERBERT
# 8743      SCHECK, RICHARD HERBERT
# 8744      SCHECK, RICHARD HERBERT
# 76712           CURCIO, BARBARA G
# 112306             WOLFF, GARY W.
# 112307             WOLFF, GARY W.
# Name: NAME, dtype: object

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
import pandas as pd 
df = pd.read_csv("/anvil/projects/tdm/data/flights/subset/1990.csv")
df.head()
#Importing new DF
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1990      1           3          3   1707.0        1630   1755.0
# 1  1990      1           4          4   1706.0        1630   1807.0
# 2  1990      1           5          5   1629.0        1630   1715.0
# 3  1990      1           6          6   1633.0        1630   1718.0
# 4  1990      1           8          1   1630.0        1630   1726.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 0        1723            US         29  ...     NaN      NaN          0
# 1        1723            US         29  ...     NaN      NaN          0
# 2        1723            US         29  ...     NaN      NaN          0
# 3        1723            US         29  ...     NaN      NaN          0
# 4        1723            US         29  ...     NaN      NaN          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df['DepDelay'][df['Origin'] == 'EWR'].mean()
# Out:
# 9.168411061736917

# %%
df['DepDelay'][df['Origin'] == 'JFK'].mean()
# Out:
# 11.857274106360704

# %%
df['DepDelay'][df['Origin'] == 'EWR'].mean()
# Out:
# 9.168411061736917

# %%
df['DepDelay'][(df['Origin'] == 'EWR') | (df['Origin'] == 'JFK') | (df['Origin'] == 'LGA') ].mean()
# Out:
# 9.400063516972109

# %%
#This code looks at all the flights from 3 different areas
#This code also takes the average DepDelay from each airport
#lasty this code will take the mean of all 3 combined

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
